# %% [markdown]
# ### Introduction to Gated Recurrent Units (GRUs)
# * What are GRUs
#     * Simplified version of Long Short term memory LSTM networks
#     * Designed to retain long-term dependencies while reducing computational complexity by having fewer parameters
#     * Key Features:
#         * Simple Architecture
#             * GrRUs have two gates(Update and reset ) compared to LSTMs  three gates (input, forget, output)
#         * Efficiency
#             * Fewer parameters make GRUs computationally faster and less prione to overfitting on smaller datasets
#         * Retains Performance
#             Compared to LSTM is performs well
#
# * Update Gate
#     * Determine how much of the previous hiddenb state to retain and how much to update with new information
# * Reset Gate
#     * Controls how much of the past information to forget when comcbining with new input
# * Hidden State Update
#     * Combines the new informations and the past hidden state based on the reset and update gates

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding, Dense, GRU
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Dense

# %%
VOCAB_SIZE = 10000
MAX_LEN = 200

# %%
(X_train,y_train),(X_test, y_test) = imdb.load_data(num_words=VOCAB_SIZE)

X_train = pad_sequences(X_train, maxlen=MAX_LEN, padding="post")
X_test =  pad_sequences(X_test, maxlen=MAX_LEN, padding="post")

print(f"Training Data Shape: {X_train.shape}")
print(f"Test Data shape : {X_test.shape}")
# Out:
# Training Data Shape: (25000, 200)
# Test Data shape : (25000, 200)

# %%
gru_model = Sequential(
    [
        Embedding(input_dim=VOCAB_SIZE, output_dim=128),
        GRU(128, activation="tanh", return_sequences=False),
        Dense(1,activation="sigmoid"),
    ]
)

gru_model.compile(optimizer="adam", loss="binary_crossentropy" , metrics=["accuracy"])
gru_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
gru_history = gru_model.fit(X_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
gru_loss,gru_accuracy = gru_model.evaluate(X_test,y_test)
print(f"GRU TEST LOSS: {gru_loss} \nGRU TEST ACCURACY: {gru_accuracy}")
# Out:
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 373s 584ms/step - accuracy: 0.5857 - loss: 0.6506 - val_accuracy: 0.8154 - val_loss: 0.4394
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 274s 412ms/step - accuracy: 0.8807 - loss: 0.2891 - val_accuracy: 0.8918 - val_loss: 0.2707
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 173s 278ms/step - accuracy: 0.9438 - loss: 0.1534 - val_accuracy: 0.8852 - val_loss: 0.2817
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 171s 274ms/step - accuracy: 0.9732 - loss: 0.0813 - val_accuracy: 0.8756 - val_loss: 0.3818
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 168s 269ms/step - accuracy: 0.9880 - loss: 0.0393 - val_accuracy: 0.8728 - val_loss: 0.4964
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.8646 - loss: 0.5244
# GRU TEST LOSS: 0.5243996977806091
# GRU TEST ACCURACY: 0.8646399974822998

# %%
gru_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (32, 200, 128)         │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (32, 128)              │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (32, 1)                │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,137,605 (15.78 MB)
#  Trainable params: 1,379,201 (5.26 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,758,404 (10.52 MB)
