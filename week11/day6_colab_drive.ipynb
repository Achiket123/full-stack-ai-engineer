# %% [markdown]
# # Sequence-to-Sequence (Seq2Seq) with Attention
#
# ## Architecture Overview
# - **Encoder**: Processes input sequence using LSTM, outputs all hidden states (not just final)
# - **Attention**: Dynamically focuses on relevant encoder states at each decoder step
# - **Decoder**: Uses attention context + previous token to generate output one token at a time
#
# ## Key Fixes from v1
# 1. **Multi-word output bug**: `tgt_indices[1:-1]` was cutting the last real word when EOS wasn't generated — fixed with conditional slicing
# 2. **Source padding during inference**: `translate_sentence` now pads input to match training length
# 3. **Encoder now returns all hidden states** for attention (not just final hidden/cell)
# 4. **Larger dataset** with more diverse sentences so the model generalizes better
# 5. **More training epochs** with learning rate scheduling
#
# ## What's new in this version
# - Replaced the 10 hand-written sentence pairs with the **real Tatoeba `fra-eng` dataset** (via manythings.org/anki)
# - The dataset is **downloaded once into the Colab VM, then cached to Google Drive** so you don't have to re-download it every session
# - Everything below the data-loading section (vocab, model, training, inference) is **unchanged** — only the data source changed

# %%
import os
import re
import shutil
import zipfile
import urllib.request

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import numpy as np
import random

# %% [markdown]
# ## Step 1 — Mount Google Drive
#
# We mount Drive first so we can cache the downloaded dataset there. After the first run, future runs will reuse the cached copy instead of re-downloading.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Folder inside your Drive where the dataset will be cached
DRIVE_DATA_DIR = '/content/drive/MyDrive/seq2seq_data'
os.makedirs(DRIVE_DATA_DIR, exist_ok=True)
print(f"Dataset will be cached at: {DRIVE_DATA_DIR}")
# Out:
# Mounted at /content/drive
# Dataset will be cached at: /content/drive/MyDrive/seq2seq_data

# %% [markdown]
# ## Step 2 — Download the `fra-eng` dataset
#
# This is the English–French sentence-pair file from the Tatoeba Project (distributed via manythings.org/anki) — the same dataset used in most seq2seq tutorials. Format per line: `English<TAB>French<TAB>attribution`.
#
# - If a cached copy already exists in Drive, we reuse it (fast, no network call).
# - Otherwise we download the zip into the **Colab VM's local disk** (`/content`), extract it, then copy `fra.txt` into Drive for next time.

# %%
# !ls
# !pwd 
DATASET_URL   = 'http://www.manythings.org/anki/fra-eng.zip'
VM_ZIP_PATH   = '/content/fra-eng.zip'
VM_EXTRACT_DIR = '/content/fra-eng'
DRIVE_TXT_PATH = os.path.join(DRIVE_DATA_DIR, 'fra.txt')

if os.path.exists(DRIVE_TXT_PATH):
    print("Found cached fra.txt in Google Drive — skipping download.")
    fra_txt_path = DRIVE_TXT_PATH
else:
    
    print("Extracting...")
    with zipfile.ZipFile(VM_ZIP_PATH, 'r') as z:
        z.extractall(VM_EXTRACT_DIR)

    vm_txt_path = os.path.join(VM_EXTRACT_DIR, 'fra.txt')

    print(f"Caching a copy to Google Drive at {DRIVE_TXT_PATH} ...")
    shutil.copy(vm_txt_path, DRIVE_TXT_PATH)

    fra_txt_path = vm_txt_path

print("Dataset ready at:", fra_txt_path)
# Out:
# drive  fra-eng.zip  sample_data
# /content
# Extracting...
# Caching a copy to Google Drive at /content/drive/MyDrive/seq2seq_data/fra.txt ...
# Dataset ready at: /content/fra-eng/fra.txt

# %% [markdown]
# ## Step 3 — Load & filter sentence pairs
#
# The raw file has ~190k pairs of every length, including long literary sentences. Since the model is word-level with a simple `.split()` tokenizer, we:
# - lowercase and strip punctuation so tokens match cleanly,
# - keep only short sentences (cheap to train on, faster convergence for a learning notebook),
# - cap the total number of pairs so training stays fast on a free Colab GPU.
#
# Tune `MAX_PAIRS` and `MAX_WORDS` below to trade off dataset size vs. training speed.

# %%
MAX_PAIRS = 4000   # how many sentence pairs to keep
MAX_WORDS = 8      # skip pairs where either sentence is longer than this

_punct_re = re.compile(r"[^a-z\u00e0-\u00ff\s']")

def clean(text):
    text = text.lower().strip()
    text = _punct_re.sub('', text)
    return re.sub(r"\s+", " ", text).strip()


def load_sentence_pairs(path, max_pairs, max_words):
    eng_out, fr_out = [], []
    with open(path, encoding='utf-8') as f:
        for line in f:
            parts = line.rstrip('\n').split('\t')
            if len(parts) < 2:
                continue
            eng, fr = clean(parts[0]), clean(parts[1])
            if not eng or not fr:
                continue
            if len(eng.split()) > max_words or len(fr.split()) > max_words:
                continue
            eng_out.append(eng)
            fr_out.append(fr)
            if len(eng_out) >= max_pairs:
                break
    return eng_out, fr_out


english_sentences, french_sentences = load_sentence_pairs(fra_txt_path, MAX_PAIRS, MAX_WORDS)

print(f"Loaded {len(english_sentences)} sentence pairs")
for eng, fr in zip(english_sentences[:5], french_sentences[:5]):
    print(f"  {eng!r:30} -> {fr!r}")
# Out:
# Loaded 4000 sentence pairs
#   'go'                           -> 'va'
#   'go'                           -> 'marche'
#   'go'                           -> 'en route'
#   'go'                           -> 'bouge'
#   'hi'                           -> 'salut'

# %% [markdown]
# ## Vocabulary & Tokenization

# %%
def build_vocab(sentences):
    vocab = {"<PAD>": 0, "<SOS>": 1, "<EOS>": 2, "<UNK>": 3}
    for sentence in sentences:
        for word in sentence.split():
            if word not in vocab:
                vocab[word] = len(vocab)
    return vocab


english_vocab = build_vocab(english_sentences)
french_vocab  = build_vocab(french_sentences)
french_idx2word = {v: k for k, v in french_vocab.items()}  # reverse lookup

print(f"English vocab size: {len(english_vocab)}")
print(f"French vocab size:  {len(french_vocab)}")


def tokenize(sentences, vocab, max_len):
    """
    Converts sentences to padded token index arrays.
    Format: [<SOS>, w1, w2, ..., <EOS>, <PAD>, <PAD>, ...]
    """
    tokenized = []
    for sentence in sentences:
        tokens = [vocab.get(w, vocab["<UNK>"]) for w in sentence.split()]
        tokens = [vocab["<SOS>"]] + tokens + [vocab["<EOS>"]]
        tokens += [vocab["<PAD>"]] * (max_len - len(tokens))
        tokenized.append(tokens)
    return np.array(tokenized)


max_len_eng = max(len(s.split()) for s in english_sentences) + 2
max_len_fr  = max(len(s.split()) for s in french_sentences) + 2

english_data = tokenize(english_sentences, english_vocab, max_len=max_len_eng)
french_data  = tokenize(french_sentences,  french_vocab,  max_len=max_len_fr)

print(f"Max source length: {max_len_eng}, Max target length: {max_len_fr}")
# Out:
# English vocab size: 992
# French vocab size:  2244
# Max source length: 6, Max target length: 10

# %% [markdown]
# ## Dataset & Model
#
# Same architecture as before. Only change: `batch_size` is bumped from `2` to `64` since we now have thousands of pairs instead of 10 — batch size 2 would make a full epoch take far too many steps on this much data.

# %%
class TranslationDataset(Dataset):
    def __init__(self, source_data, target_data):
        self.src = source_data
        self.tgt = target_data

    def __len__(self):
        return len(self.src)

    def __getitem__(self, idx):
        return torch.tensor(self.src[idx], dtype=torch.long), \
               torch.tensor(self.tgt[idx], dtype=torch.long)


dataset   = TranslationDataset(english_data, french_data)
dataloader = DataLoader(dataset, batch_size=64, shuffle=True)


# ── Encoder ─────────────────────────────────────────────────
class Encoder(nn.Module):
    """
    LSTM encoder. Returns ALL hidden states (enc_outputs) so the attention
    mechanism can attend over the full input sequence.
    """
    def __init__(self, input_dim, embed_dim, hidden_dim, num_layers, dropout=0.3):
        super().__init__()
        self.embedding = nn.Embedding(input_dim, embed_dim, padding_idx=0)
        self.lstm      = nn.LSTM(embed_dim, hidden_dim, num_layers,
                                 batch_first=True, dropout=dropout if num_layers > 1 else 0)
        self.dropout   = nn.Dropout(dropout)

    def forward(self, x):
        embedded       = self.dropout(self.embedding(x))   # (B, src_len, embed)
        enc_out, (h, c) = self.lstm(embedded)              # enc_out: (B, src_len, hidden)
        return enc_out, h, c


# ── Attention ─────────────────────────────────────────────────
class BahdanauAttention(nn.Module):
    """
    Additive (Bahdanau) attention.
    Score(s, h) = v · tanh(W_s · s + W_h · h)
    """
    def __init__(self, hidden_dim):
        super().__init__()
        self.W_s  = nn.Linear(hidden_dim, hidden_dim, bias=False)
        self.W_h  = nn.Linear(hidden_dim, hidden_dim, bias=False)
        self.v    = nn.Linear(hidden_dim, 1, bias=False)

    def forward(self, decoder_hidden, encoder_outputs):
        """
        decoder_hidden  : (B, hidden)  — top-layer decoder hidden state
        encoder_outputs : (B, src_len, hidden)
        returns context : (B, hidden)
        """
        src_len = encoder_outputs.size(1)
        # Expand decoder state to match every encoder step
        dec = decoder_hidden.unsqueeze(1).repeat(1, src_len, 1)  # (B, src_len, hidden)
        energy  = torch.tanh(self.W_s(dec) + self.W_h(encoder_outputs))  # (B, src_len, hidden)
        scores  = self.v(energy).squeeze(-1)                              # (B, src_len)
        weights = F.softmax(scores, dim=1)                                # (B, src_len)
        context = torch.bmm(weights.unsqueeze(1), encoder_outputs)        # (B, 1, hidden)
        return context.squeeze(1), weights


# ── Decoder ─────────────────────────────────────────────────
class Decoder(nn.Module):
    """
    LSTM decoder with Bahdanau attention.
    Input to LSTM at each step = [embedding; attention_context]
    """
    def __init__(self, output_dim, embed_dim, hidden_dim, num_layers, dropout=0.3):
        super().__init__()
        self.embedding  = nn.Embedding(output_dim, embed_dim, padding_idx=0)
        self.attention  = BahdanauAttention(hidden_dim)
        # LSTM input = embed + context vector
        self.lstm       = nn.LSTM(embed_dim + hidden_dim, hidden_dim, num_layers,
                                  batch_first=True, dropout=dropout if num_layers > 1 else 0)
        self.fc         = nn.Linear(hidden_dim * 2, output_dim)  # hidden + context → vocab
        self.dropout    = nn.Dropout(dropout)

    def forward(self, x, hidden, cell, encoder_outputs):
        """
        x               : (B,)          — current input token index
        hidden / cell   : (layers, B, hidden)
        encoder_outputs : (B, src_len, hidden)
        """
        x        = x.unsqueeze(1)                           # (B, 1)
        embedded = self.dropout(self.embedding(x))          # (B, 1, embed)

        # Attention over all encoder steps
        top_hidden       = hidden[-1]                       # (B, hidden) — top LSTM layer
        context, weights = self.attention(top_hidden, encoder_outputs)  # (B, hidden)
        context_expanded = context.unsqueeze(1)            # (B, 1, hidden)

        lstm_input = torch.cat([embedded, context_expanded], dim=2)     # (B, 1, embed+hidden)
        out, (hidden, cell) = self.lstm(lstm_input, (hidden, cell))     # out: (B, 1, hidden)

        out     = out.squeeze(1)                            # (B, hidden)
        pred    = self.fc(torch.cat([out, context], dim=1))# (B, output_dim)
        return pred, hidden, cell, weights


# ── Seq2Seq wrapper ──────────────────────────────────────────
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.device  = device

    def forward(self, src, tgt, teacher_forcing_ratio=0.5):
        B, tgt_len       = tgt.size()
        tgt_vocab_size   = self.decoder.fc.out_features
        outputs          = torch.zeros(B, tgt_len, tgt_vocab_size).to(self.device)

        enc_out, hidden, cell = self.encoder(src)
        inp = tgt[:, 0]                        # first input = <SOS>

        for t in range(1, tgt_len):
            output, hidden, cell, _ = self.decoder(inp, hidden, cell, enc_out)
            outputs[:, t, :]        = output
            top1 = output.argmax(1)
            # Teacher forcing: sometimes feed the gold label, sometimes the prediction
            inp  = tgt[:, t] if random.random() < teacher_forcing_ratio else top1

        return outputs


# ── Instantiate ────────────────────────────────────────────
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_dim  = len(english_vocab)
output_dim = len(french_vocab)
embed_dim  = 128
hidden_dim = 256
num_layers = 2

encoder = Encoder(input_dim,  embed_dim, hidden_dim, num_layers)
decoder = Decoder(output_dim, embed_dim, hidden_dim, num_layers)
model   = Seq2Seq(encoder, decoder, device).to(device)

total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Model parameters: {total_params:,}")
# Out:
# Model parameters: 3,802,052

# %% [markdown]
# ## Training
#
# Same training loop as before. With thousands of pairs you'll likely want more than 10 epochs to converge — bumped to 15 here as a reasonable starting point; raise it further if loss is still dropping steadily at the end.

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)
# Reduce LR when loss plateaus
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5)
criterion = nn.CrossEntropyLoss(ignore_index=french_vocab["<PAD>"])


def train(model, dataloader, optimizer, scheduler, criterion, device, num_epochs=20):
    model.train()
    for epoch in range(num_epochs):
        epoch_loss = 0
        for src, tgt in dataloader:
            src, tgt = src.to(device), tgt.to(device)
            optimizer.zero_grad()

            output = model(src, tgt)                            # (B, tgt_len, vocab)
            output = output[:, 1:].reshape(-1, output.shape[2])# skip <SOS> prediction
            target = tgt[:, 1:].reshape(-1)                    # skip <SOS> in target

            loss = criterion(output, target)
            loss.backward()
            # Gradient clipping prevents exploding gradients
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(dataloader)
        scheduler.step(avg_loss)
        
        print(f"Epoch {epoch+1:3d}: Loss = {avg_loss:.4f}")


train(model, dataloader, optimizer, scheduler, criterion, device, num_epochs=15)
# Out:
# Epoch   1: Loss = 1.7617
# Epoch   2: Loss = 1.5209
# Epoch   3: Loss = 1.4120
# Epoch   4: Loss = 1.3291
# Epoch   5: Loss = 1.2569
# Epoch   6: Loss = 1.1861
# Epoch   7: Loss = 1.1325
# Epoch   8: Loss = 1.0799
# Epoch   9: Loss = 1.0350
# Epoch  10: Loss = 0.9767
# Epoch  11: Loss = 0.9399
# Epoch  12: Loss = 0.9100
# Epoch  13: Loss = 0.8861
# Epoch  14: Loss = 0.8545
# Epoch  15: Loss = 0.8238

# %% [markdown]
# ## Inference
#
# ### Fix applied here:
# - Input is **padded to `max_len_eng`** (same as training) — prevents length mismatch
# - `tgt_indices[1:-1]` is replaced with conditional slicing that **doesn't drop the last token** unless EOS is present
#
# With thousands of training pairs, printing every single one would flood the output — the test loop below now checks a **random sample** of 20 sentences plus a couple of free-form custom phrases instead of the entire dataset.

# %%
def translate_sentence(model, sentence, eng_vocab, fr_vocab, fr_idx2word,
                       max_len_eng, max_len_fr, device):
    model.eval()

    # ── Tokenise & pad source (must match training format) ──
    tokens = [eng_vocab.get(w, eng_vocab["<UNK>"]) for w in sentence.split()]
    tokens = [eng_vocab["<SOS>"]] + tokens + [eng_vocab["<EOS>"]]
    # Pad to max_len_eng so the encoder sees the same length it trained on
    tokens += [eng_vocab["<PAD>"]] * max(0, max_len_eng - len(tokens))
    src = torch.tensor(tokens[:max_len_eng]).unsqueeze(0).to(device)  # (1, max_len_eng)

    with torch.no_grad():
        enc_out, hidden, cell = model.encoder(src)

        generated = [fr_vocab["<SOS>"]]
        for _ in range(max_len_fr):
            inp = torch.tensor([generated[-1]]).to(device)             # (1,)
            out, hidden, cell, _ = model.decoder(inp, hidden, cell, enc_out)
            pred = out.argmax(1).item()
            generated.append(pred)
            if pred == fr_vocab["<EOS>"]:
                break

    # ── FIX: only strip trailing EOS; don't blindly drop the last token ──
    tokens_out = generated[1:]                  # drop leading <SOS>
    if tokens_out and tokens_out[-1] == fr_vocab["<EOS>"]:
        tokens_out = tokens_out[:-1]            # drop trailing <EOS> if present

    words = [fr_idx2word.get(i, "<UNK>") for i in tokens_out
             if i not in (fr_vocab["<PAD>"], fr_vocab["<UNK>"])]
    return " ".join(words)


# ── Test on a random sample of training sentences ──
sample_idx = random.sample(range(len(english_sentences)), k=min(20, len(english_sentences)))

print("=" * 60)
print(f"{'English':<28} {'Predicted':>28}")
print("=" * 60)
for i in sample_idx:
    eng, expected_fr = english_sentences[i], french_sentences[i]
    translation = translate_sentence(
        model, eng, english_vocab, french_vocab, french_idx2word,
        max_len_eng, max_len_fr, device
    )
    match = "✓" if translation == expected_fr else "✗"
    print(f"{match} {eng:<26} → {translation}")
    print(f"  (expected: {expected_fr})")

# ── Free-form custom phrases ──
for custom in ["how are you", "thank you", "who are you", "are you in kitchen"]:
    print(f"\n{custom!r} -> {translate_sentence(model, custom, english_vocab, french_vocab, french_idx2word, max_len_eng, max_len_fr, device)!r}")
# Out:
# ============================================================
# English                                         Predicted
# ============================================================
# ✗ i can't see                → je ne peux pas voir
#   (expected: je suis aveugle)
# ✗ are you hot                → astu chaud
#   (expected: avezvous chaud)
# ✗ really                     → ah vraiment
#   (expected: vraiment)
# ✗ let me go                  → laissezmoi m'en aller
#   (expected: laissemoi m'en aller)
# ✗ nice timing                → pile calculé
#   (expected: tout juste)
# ✗ go ahead                   → vasy
#   (expected: allezy)
# ✗ get away                   → pars
#   (expected: fiche le camp)
# ✗ is it yours                → estce le vôtre
#   (expected: estce la vôtre)
# ✓ i'm taller                 → je suis plus grand
#   (expected: je suis plus grand)
# ✗ hold it                    → ne bouge plus
#   (expected: ne bougez plus)
# ✗ don't argue                → ne discute pas
#   (expected: ne discutez pas)
# ✗ am i clear                 → suisje claire
#   (expected: suisje clair)
# ✓ he is nasty                → il est méchant
#   (expected: il est méchant)
# ✗ i use it                   → je l'utilise
#   (expected: je m'en sers)
# ✓ we forgot                  → nous avons oublié
#   (expected: nous avons oublié)
# ✓ wait a bit                 → attends une seconde
#   (expected: attends une seconde)
# ✓ i'm sneaky                 → je suis sournois
#   (expected: je suis sournois)
# ✓ tom stayed                 → tom est resté
#   (expected: tom est resté)
# ✗ of course                  → mais sûr
#   (expected: mais ouais)
# ✗ run                        → fuyons
#   (expected: prenez vos jambes à vos cous)
#
# 'how are you' -> 'comment va'
#
# 'thank you' -> 'merci'
#
# 'who are you' -> 'qui estce'
#
# 'are you in kitchen' -> 'estu partant'
